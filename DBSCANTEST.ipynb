# %%
from sklearn.cluster import DBSCAN
from shapely.geometry import MultiPoint
import pandas as pd
import datetime
from dateutil import parser
import numpy as np
import geopandas as gpd
from dateutil import parser

# %%
datafile='C:\File\GISFile.csv'

# %%
data=pd.read_csv(datafile)

# %%
 data.Date=[parser.parse(t).date() for t in data.Date]

# %%
data
# Out:
#             lon        lat PATIENT_IDENTIFIER        Date              x  \
# 0    -81.624544  41.469299          E37730375  2020-04-29  447849.087885
# 1    -81.807257  41.479861           E5377021  2020-05-17  432602.947500
# 2    -81.527352  41.535256       E14038723116  2020-06-25  456009.544502
# 3    -81.860125  41.467062       E15040036023  2020-05-05  428174.884570
# 4    -81.578029  41.139601       E14042127130  2020-04-07  451489.478252
# 5    -82.045827  41.462269           E4810254  2020-03-25  412661.129149
# 6    -81.994647  41.387349       E14039728058  2020-03-23  416839.772009
# 7    -80.258361  25.947707       E14041383766  2020-06-06  574255.619703
# 8    -82.161045  41.472538          E37471583  2020-04-14  403054.213072
# 9    -80.203205  25.770398       E14044978365  2020-06-25  579897.368939
# 10   -81.556368  41.126187           E5749817  2020-03-31  453297.852309
# 11   -81.737685  41.470294       E14041968439  2020-06-29  438402.426436
# 12   -81.527124  41.386690           E5821141  2020-06-18  455928.090859
# 13   -80.337792  25.951486       E14044983773  2020-06-27  566300.346354
# 14   -81.494205  41.572117           E5812118  2020-07-11  458798.012279
# 15   -80.206560  25.986968       E14044664881  2020-05-01  579415.958524
# 16   -81.786954  41.139394           E5169292  2020-05-12  433955.312625
# 17   -80.857348  41.880190       E14041160522  2020-04-22  511836.235975
# 18   -81.442054  41.414802           E5128436  2020-05-16  463056.587712
# 19   -81.583997  41.441811       E13040022902  2020-05-27  451214.280809
# 20   -80.184065  26.033938       E14044641570  2020-04-04  581635.102906
# 21   -82.071633  41.399755           E5562712  2020-04-11  410420.086504
# 22   -81.774870  41.453698       E14039354508  2020-05-17  435280.912022
# 23   -81.732217  41.439384       E14039573282  2020-05-30  438829.979419
# 24   -81.936256  41.429171       E14039560574  2020-03-28  421771.958207
# 25   -81.591107  41.441674       E14038708373  2020-06-02  450620.221837
# 26   -81.597708  41.481476          E37653928  2020-05-03  450099.308829
# 27   -81.533441  41.600232       E14043368192  2020-06-02  455546.176211
# 28   -81.923619  41.137433           E5350390  2020-04-22  422483.342193
# 29   -80.077804  26.461443       E14044687102  2020-06-02  591930.088587
# ...         ...        ...                ...         ...            ...
# 1969 -81.685663  40.944366       E14040628815  2020-03-31  442286.034206
# 1970 -81.505375  41.587710           E5653930  2020-05-06  457876.897966
# 1971 -81.352309  41.496602           E5206199  2020-05-08  470593.754903
# 1972 -81.482953  40.521333       E14044017949  2020-05-12  459090.419045
# 1973 -81.413952  41.342365       E13039953778  2020-06-03  465366.731451
# 1974 -81.693665  41.431888       E15040246484  2020-05-01  442043.998250
# 1975 -81.782993  41.445903       E14039085852  2020-06-17  434594.624290
# 1976 -81.545069  41.536436           E6040107  2020-06-30  454532.455334
# 1977 -81.627493  41.517314           E4985092  2020-03-29  447641.518315
        start_date=np.min(data.Date.values)

# %%
recheader=['id','centroid_x','centroid_y']

# %%
start_date
# Out:
# datetime.date(2020, 1, 7)

# %%
end_date=datetime.datetime.now().date()

# %%
 datevals=[start_date+datetime.timedelta(days=i) for i in range((end_date-start_date).days+1)]

# %%
  recheader.extend(datevals)

# %%
 gpframe=gpd.GeoDataFrame(data,geometry=gpd.points_from_xy(data.lon, data.lat))

# %%
gpframe.crs={'init': 'epsg:4326'}
gpframe=gpframe.to_crs({'init': 'epsg:26917'})
data['x']=[geom.x for geom in gpframe.geometry]
data['y']=[geom.y for geom in gpframe.geometry]

# %%
data=data.drop(columns=['geometry'])

# %%
    xy=data[['x','y']].values

# %%
xy
# Out:
# array([[ 447849.08788542, 4591044.05954433],
#        [ 432602.94750043, 4592342.90169444],
#        [ 456009.54450162, 4598312.56492716],
#        ...,
#        [ 455400.30244077, 4521919.84295097],
#        [ 592802.50690859, 2937230.42149944],
#        [ 436044.74097307, 4575752.3308105 ]])

# %%
    latlon=data[['lon','lat']].values

# %%
latlon
# Out:
# array([[-81.624544,  41.469299],
#        [-81.807257,  41.479861],
#        [-81.527352,  41.535256],
#        ...,
#        [-81.529086,  40.847111],
#        [-80.068317,  26.55269 ],
#        [-81.764283,  41.330715]])

# %%
    dates=data['Date'].values

# %%
dates
# Out:
# array([datetime.date(2020, 4, 29), datetime.date(2020, 5, 17),
#        datetime.date(2020, 6, 25), ..., datetime.date(2020, 3, 26),
#        datetime.date(2020, 4, 19), datetime.date(2020, 5, 25)],
#       dtype=object)

# %%
 clusterData=pd.DataFrame(columns=recheader)

# %%
  clustering = DBSCAN(eps=100, min_samples=2,algorithm='kd_tree').fit(xy)

# %%
labels = clustering.labels_
total_clusters = len(set(labels))
k=0
geometries=[]
ids=[]

# %%
labels
# Out:
# array([-1, -1, -1, ..., -1, -1, 36], dtype=int64)

# %%
total_clusters
# Out:
# 176

# %%
for i in range(total_clusters):
        ltln=latlon[labels==i]
        date=dates[labels==i]
        prjpoints=xy[labels==i]
        if len(ltln)!=0 and len(ltln)>=minneighbors:
            tdframe=pd.DataFrame(columns=['date'])
            tdframe.date=datevals
            newdframe=pd.DataFrame(columns=['date','counts'])
            #aggregate counts based on date
            unique, counts = np.unique(Date, return_counts=True)
            newdframe.date=unique
            newdframe.counts=counts
            tdframe=tdframe.merge(newdframe,on='Date',how='outer')
            tdframe=tdframe.fillna(0)
            #cumulative sum for the dates
            cnts=np.cumsum(tdframe.counts.values)
            #set zero for total neighbors
            cnts[cnts<minneighbors]=0
            tdframe.counts=cnts
            #for generating centroids
            geom=MultiPoint(ltln)
            dat=[k,geom.centroid.x,geom.centroid.y]
            ids.append(k)
            geom_proj=MultiPoint(prjpoints)
            #convex hulls based on all members
            geom_hull=geom_proj.convex_hull
            if geom_hull.geom_type!='Polygon':
                geom_hull=geom_hull.buffer(maxdistance)
            geometries.append(geom_hull)
            dat.extend(tdframe.counts.values.tolist())
            clusterData.loc[len(clusterData)]=dat
            k+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-a29284eec2e7> in <module>
#       8             newdframe=pd.DataFrame(columns=['date','counts'])
#       9             #aggregate counts based on date
# ---> 10             unique, counts = np.unique(Date, return_counts=True)
#      11             newdframe.date=unique
#      12             newdframe.counts=counts
#
# NameError: name 'Date' is not defined

# %%
minneighbors=2

# %%
for i in range(total_clusters):
        ltln=latlon[labels==i]
        date=dates[labels==i]
        prjpoints=xy[labels==i]

# %%
if len(ltln)!=0 and len(ltln)>=minneighbors:
            tdframe=pd.DataFrame(columns=['date'])
            tdframe.date=datevals
            newdframe=pd.DataFrame(columns=['date','counts'])

# %%
unique, counts = np.unique(date, return_counts=True)
newdframe.date=unique
newdframe.counts=counts
tdframe=tdframe.merge(newdframe,on='date',how='outer')

# %%
tdframe=tdframe.fillna(0)

# %%
tdframe
# Out:
#            date  counts
# 0    2019-04-06     0.0
# 1    2019-04-07     0.0
# 2    2019-04-08     0.0
# 3    2019-04-09     0.0
# 4    2019-04-10     0.0
# 5    2019-04-11     0.0
# 6    2019-04-12     0.0
# 7    2019-04-13     0.0
# 8    2019-04-14     0.0
# 9    2019-04-15     0.0
# 10   2019-04-16     0.0
# 11   2019-04-17     0.0
# 12   2019-04-18     0.0
# 13   2019-04-19     0.0
# 14   2019-04-20     0.0
# 15   2019-04-21     0.0
# 16   2019-04-22     0.0
# 17   2019-04-23     0.0
# 18   2019-04-24     0.0
# 19   2019-04-25     0.0
# 20   2019-04-26     0.0
# 21   2019-04-27     0.0
# 22   2019-04-28     0.0
# 23   2019-04-29     0.0
# 24   2019-04-30     0.0
# 25   2019-05-01     0.0
# 26   2019-05-02     0.0
# 27   2019-05-03     0.0
# 28   2019-05-04     0.0
# 29   2019-05-05     0.0
# ..          ...     ...
# 438  2020-06-17     0.0
# 439  2020-06-18     0.0
# 440  2020-06-19     0.0
# 441  2020-06-20     0.0
# 442  2020-06-21     0.0
# 443  2020-06-22     0.0
# 444  2020-06-23     0.0
# 445  2020-06-24     0.0
# 446  2020-06-25     0.0
# 447  2020-06-26     0.0
# 448  2020-06-27     0.0
# 449  2020-06-28     0.0
# 450  2020-06-29     0.0
# 451  2020-06-30     0.0
# 452  2020-07-01     0.0
# 453  2020-07-02     0.0
# 454  2020-07-03     0.0
# 455  2020-07-04     0.0
# 456  2020-07-05     0.0
# 457  2020-07-06     0.0
# 458  2020-07-07     0.0
# 459  2020-07-08     0.0
# 460  2020-07-09     0.0
# 461  2020-07-10     0.0
# 462  2020-07-11     0.0
# 463  2020-07-12     0.0
# 464  2020-07-13     0.0
# 465  2020-07-14     0.0
# 466  2020-07-15     0.0
# 467  2020-07-16     0.0
#
# [468 rows x 2 columns]

# %%
cnts=0

# %%
tdframe.counts=cnts

# %%
geom=MultiPoint(ltln)

# %%
geom

# %%
            dat=[k,geom.centroid.x,geom.centroid.y]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-1f50b346094d> in <module>
# ----> 1 dat=[k,geom.centroid.x,geom.centroid.y]
#       2
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\shapely\geometry\point.py in x(self)
#      54     def x(self):
#      55         """Return x coordinate."""
# ---> 56         return self.coords[0][0]
#      57
#      58     @property
#
# IndexError: list index out of range
